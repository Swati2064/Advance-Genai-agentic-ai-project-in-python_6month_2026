# %% [markdown]
# # Variable declaration in Python (variable = object = identifiers)
#
# - variable=value

# %%
nit=1030
nit
# Out:
# 1030

# %%
1030=nit
# Out:
#   Cell In[113], line 1
#     1030=nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1nit=10
1nit

# %%
nit1=20
nit1
# Out:
# 20

# %%
nit1=10
NLT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 2
#       1 nit1=10
# ----> 2 NLT
#
# NameError: name 'NLT' is not defined

# %%
nit
# Out:
# 1030

# %%
nit1
# Out:
# 10

# %%
nit@=7
nit@
# Out:
#   Cell In[125], line 2
#     nit@
#         ^
# SyntaxError: invalid syntax

# %%
nit_=30
nit_
# Out:
# 30

# %%
nit$=2
nit$
# Out:
#   Cell In[129], line 1
#     nit$=2
#        ^
# SyntaxError: invalid syntax

# %%
_nit=5
_nit
# Out:
# 5

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
for=45
for
# Out:
#   Cell In[137], line 1
#     for=45
#        ^
# SyntaxError: invalid syntax

# %%
For=50
For
# Out:
# 50

# %%
if=60
if
# Out:
#   Cell In[141], line 1
#     if=60
#       ^
# SyntaxError: invalid syntax

# %%
else=65
else
# Out:
#   Cell In[143], line 1
#     else=65
#     ^
# SyntaxError: invalid syntax

# %%
true=7
true
# Out:
# 7

# %%
a=true
a
# Out:
# 7

# %% [markdown]
# # python veriable are completed

# %% [markdown]
# # Python DataTypes (Integer, Float, Boolean, Complex)

# %%
i=10
i
# Out:
# 10

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140727340509912

# %%
type(10)
# Out:
# int

# %%
f=5.4
f
# Out:
# 5.4

# %%
type(f)
# Out:
# float

# %%
type(5.4)
# Out:
# float

# %%
gold_price=148000.78
gold_price
# Out:
# 148000.78

# %%
type(gold_price)
# Out:
# float

# %%
20+5
20-5
20*5
# Out:
# 100

# %%
print(20+5)
print(20-5)
print(20*5)
# Out:
# 25
# 15
# 100

# %%
f1=4e1
f1
# Out:
# 40.0

# %%
f1=2.4e1
f1
# Out:
# 24.0

# %%
type(f1)
# Out:
# float

# %%
len(f1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 len(f1)
#
# TypeError: object of type 'float' has no len()

# %%
id(f1)
# Out:
# 2980186037712

# %%
f2=4.5e2
f2
# Out:
# 450.0

# %%
f3=3.5e3
f3
# Out:
# 3500.0

# %%
f4=1.5e8
f4
# Out:
# 150000000.0

# %%
f5=1e1
f5
# Out:
# 10.0

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+True
# Out:
# 2

# %%
False+True
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
True+False-False
# Out:
# 1

# %%
True+False+False
# Out:
# 1

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
c=20+40j # 20 is a real part & 40 is a imaginary part ; where j is a squre root of -1
c
# Out:
# (20+40j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 20.0

# %%
c.imag
# Out:
# 40.0

# %% [markdown]
# # Python veriable

# %%
age=(25) # here, 'age' is a veriable & it is stores an integer value 25
print(age)
# Out:
# 25

# %%
name="Swati" # here, 'name' is a variable & it stores an string value "Swati"
print(name)
# Out:
# Swati

# %%
price=20.45 # 'price' is a variable ,storing float value
print(price)
# Out:
# 20.45

# %%
is_active=True # 'is_active' is a veriable & storing a boolean value 
print(is_active)
# Out:
# True

# %%
# storing and  printing a value
x=20
print(x)
# Out:
# 20

# %%
# Using Variables in Expressions
a=5
b=6
result=a+b
print(result)
# Out:
# 11

# %%
# changing the value of a veriable
score=(25)
print(score)
#changing value
score=50
print(score)
# Out:
# 25
# 50

# %%
# Concatenations srting
# Assigning values to variables
first_name="john"
last_name="Doe"

#concatenating string and storing  in a new value
full_name=first_name+' '+last_name
print(full_name)
# Out:
# john Doe

# %%
# Using Variables in a calculation
# Assigning values to variables
lenth=5
width=3

# calculating the area of rectangle
area=lenth*width
print(area)
# Out:
# 15

# %%
# Reassigning Values to veriables
x=10
print(x)
# Reassigning  the value of x
x=20
print(x)
# Out:
# 10
# 20

# %%
# Variables in python

first_name='Swati'
last_name='Jadhav'
country='India'
city='Hyderabad'
age=21
is_married=False
skills=['python', 'SQL', 'HTML']
person_info={
    'firstname':'Alice',
    'lastname':'Deo',
    'country':'America',
    'city':'Landon'
}

    # printing the value  storing in a veriables
print('First name:',first_name)
print('First name length:',len(first_name))
print('Last name:',last_name)
print('Last name length:',len(last_name))
print('Country:',country)
print('City:',city)
print('Age:',age)
print('Married:',is_married)
print('Skills:',skills)
print('Person information:',person_info)

# Declaration multiple variables in one line

first_name,last_name,country,city,age,is_married='Swati','Jadhav','India','Hyderabad',21,False

print(first_name,last_name,country,city,age,is_married)
print('First name :',first_name)
print('Last name:',last_name)
print('Country:',country)
print('City:',city)
print('Age:',age)
print('Married:',is_married)
# Out:
# First name: Swati
# First name length: 5
# Last name: Jadhav
# Last name length: 6
# Country: India
# City: Hyderabad
# Age: 21
# Married: False
# Skills: ['python', 'SQL', 'HTML']
# Person information: {'firstname': 'Alice', 'lastname': 'Deo', 'country': 'America', 'city': 'Landon'}
# Swati Jadhav India Hyderabad 21 False
# First name : Swati
# Last name: Jadhav
# Country: India
# City: Hyderabad
# Age: 21
# Married: False

# %% [markdown]
# # String

# %%
s='python'
s
# Out:
# 'python'

# %%
s1='welcome'
s1
# Out:
# 'welcome'

# %%
s1[3]
# Out:
# 'c'

# %%
s1[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[255], line 1
# ----> 1 s1[9]
#
# IndexError: string index out of range

# %%
s1
# Out:
# 'welcome'

# %%
s1[-5]
# Out:
# 'l'

# %%
s1
# Out:
# 'welcome'

# %%
len(s1)
# Out:
# 7

# %%
s1[6]
# Out:
# 'e'

# %%
s1
# Out:
# 'welcome'

# %%
s1[:]
# Out:
# 'welcome'

# %%
s1[1:4] #forward slicing
# Out:
# 'elc'

# %%
s1
# Out:
# 'welcome'

# %%
s2='nareshtechnology'
s2
# Out:
# 'nareshtechnology'

# %%
s2[:]
# Out:
# 'nareshtechnology'

# %%
len(s2)
# Out:
# 16

# %%
s2
# Out:
# 'nareshtechnology'

# %%
s2[0:]
# Out:
# 'nareshtechnology'

# %%
s2
# Out:
# 'nareshtechnology'

# %%
s2[:6]
# Out:
# 'naresh'

# %%
s2
# Out:
# 'nareshtechnology'

# %%
s2[:3]
# Out:
# 'nar'

# %%
s2
# Out:
# 'Word'

# %% [markdown]
# # String Creation

# %%
str1='Hello Python'
print(str1)
# Out:
# Hello Python

# %%
mystr='Hello word'
print(mystr)
# Out:
# Hello word

# %%
mystr1="Hello word"
print(mystr1)
# Out:
# Hello word

# %%
mystr='''hello word'''
print(mystr)
# Out:
# hello word

# %%
mystr = ('Happy', 'Monday', 'Everyday')
print(mystr)
# Out:
# ('Happy', 'Monday', 'Everyday')

# %%
mystr2="Hello"
mystr2=mystr2*5
print(mystr2)
# Out:
# HelloHelloHelloHelloHello

# %%
len(mystr2)
# Out:
# 25

# %%
str="Python Programming"
str
# Out:
# 'Python Programming'

# %%
str[0]
# Out:
# 'P'

# %%
str[len(str)-1]
# Out:
# 'g'

# %%
len(str)
# Out:
# 18

# %%
str[-1]
# Out:
# 'g'

# %%
str[6]
# Out:
# ' '

# %%
str[15]
# Out:
# 'i'

# %%
str[7]
# Out:
# 'P'

# %% [markdown]
# # String Slicing

# %%
str[0:7]
# Out:
# 'Python '

# %%
str[:100]
# Out:
# 'Python Programming'

# %%
str[100:]
# Out:
# ''

# %%
str[6:12]
# Out:
# ' Progr'

# %%
str[-4:]
# Out:
# 'ming'

# %%
str[-6:]
# Out:
# 'amming'

# %%
str[:4]
# Out:
# 'Pyth'

# %%
str[:6]
# Out:
# 'Python'

# %%
str1="PythonProgramming"
str1
# Out:
# 'PythonProgramming'

# %%
str1[1:5]
# Out:
# 'ytho'

# %%
str1[1:8:3]
# Out:
# 'yor'

# %%
str1[::1]
# Out:
# 'PythonProgramming'

# %%
str1[::2]
# Out:
# 'PtoPormig'

# %%
str1[::3]
# Out:
# 'PhPgmn'

# %%
str1[::-1]
# Out:
# 'gnimmargorPnohtyP'

# %%
str1[::-2]
# Out:
# 'gimroPotP'

# %% [markdown]
# # Update & Delete String

# %%
str
# Out:
# 'Python Programming'

# %%
#String Are immutable which mean elements of a string cannot be changed once time
str[0:5]
# Out:
# 'Pytho'

# %%
del str
print(str)
# Out:
# <class 'str'>

# %% [markdown]
# # String concatenation

# %%
s1='Hello'
s2='Word'
s3=s1+s2
print(s3)
# Out:
# HelloWord

# %% [markdown]
# # Python Tutorial

# %% [markdown]
# # Keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # Indentifiers

# %%
import=125
# Out:
#   Cell In[361], line 1
#     import=125
#           ^
# SyntaxError: invalid syntax

# %%
1var=10
# Out:
#   Cell In[363], line 1
#     1var=10
#     ^
# SyntaxError: invalid decimal literal

# %%
val12@=35
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[365], line 1
# ----> 1 val12@=35
#
# NameError: name 'val12' is not defined

# %%
"""
correct way of defining an identifier
Identifiers can be a combination of letters in lowercase (a to Z) or uppercase
"""
va12=10

# %%
val_=99

# %% [markdown]
# # Comments in Python

# %%
#Single line comment
vall=10

# %%
# Multiple
# line
# comments
vall=10

# %%
"""
Multiple
line
comment
"""
vall=10

# %% [markdown]
# # Statements

# %%
p=20 #create an integer object with value 20 and assigns the variable p to p
q=20 #create new reference q which will point to value 20.p & q will be poi
r=q  # variable r will also point to the same location where p & q are pointin 
p,type(p), hex(id(p)) # Variable p is pointing to memory location '0xfff6d71a'
# Out:
# (20, int, '0x7ffda3242c18')

# %%
q,type(q), hex(id(q))
# Out:
# (20, int, '0x7ffda3242c18')

# %%
r,type(r),hex(id(r))
# Out:
# (20, int, '0x7ffda3242c18')

# %%
p=20
p=p+10 # variable Overwriting
p
# Out:
# 30

# %% [markdown]
# # Variable Assigment

# %%
intvar=10 # Integer variable
floatvar=2.57 # float variable
strvar="Python Language"# string Variable

print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %% [markdown]
# # Multiple Assignments

# %%
intvar,floatvar,strvar=10,2.57,"Python Language" # Using commas to separat
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %%
p1=p2=p3=p4=44 # all variables pointing to same value
print(p1,p2,p3,p4)
# Out:
# 44 44 44 44

# %% [markdown]
# # Data Types

# %% [markdown]
# # Numeric

# %%
val1=10 # integer data type
print(val1)
print(type(val1)) # type of object
print(sys.getsizeof(val1)) # size of integer object in bytes
print(vall,"is integer",isinstance(val1,int)) # val1 is an instance of int
# Out:
# 10
# <class 'int'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[397], line 4
#       2 print(val1)
#       3 print(type(val1)) # type of object
# ----> 4 print(sys.getsizeof(val1)) # size of integer object in bytes
#       5 print(vall,"is integer",isinstance(val1,int))
#
# NameError: name 'sys' is not defined

# %%
val2=20.5
print(val2)
print(type(val2))
print(sys.getsizeof(val2))
print(val2,"is float",isinstance(val2,float))
# Out:
# 20.5
# <class 'float'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[399], line 4
#       2 print(val2)
#       3 print(type(val2))
# ----> 4 print(sys.getsizeof(val2))
#       5 print(val2,"is float",isinstance(val2,float))
#
# NameError: name 'sys' is not defined

# %%
val3=10+20j
print(val3)
print(type(val3))
print(sys.getsizeof(val3))
print(val2,"is complex",isinstance(val3,complex))
# Out:
# (10+20j)
# <class 'complex'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[401], line 4
#       2 print(val3)
#       3 print(type(val3))
# ----> 4 print(sys.getsizeof(val3))
#       5 print(val2,"is complex",isinstance(val3,complex))
#
# NameError: name 'sys' is not defined

# %%
sys.getsizeof(int())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[403], line 1
# ----> 1 sys.getsizeof(int())
#
# NameError: name 'sys' is not defined

# %%
sys.getsizeof(float())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[405], line 1
# ----> 1 sys.getsizeof(float())
#
# NameError: name 'sys' is not defined

# %%
sys.getsizeof(complex())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[407], line 1
# ----> 1 sys.getsizeof(complex())
#
# NameError: name 'sys' is not defined

# %% [markdown]
# # Boolean

# %%
bool1=True

# %%
bool2=False

# %%
print(type(bool1))
print(type(bool2))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
isinstance(bool1,bool)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(False)
# Out:
# False

# %% [markdown]
# # Python Type casting
# - car()=car function without argument
# - asian_car('tata','to')=car function with 2 argument|type of argument string
# - german_car('audi','bmw','fereri','vw')=car with 4 arguments

# %% [markdown]
# # Type cast All Other data type to integer

# %%
int(5.2)
# Out:
# 5

# %%
int(1.3,3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int(1.3,3.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(20)
# Out:
# 20

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # Other datatype to float

# %%
float(5)
# Out:
# 5.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(-5)
# Out:
# -5.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 float(2,3)
#
# TypeError: float expected at most 1 argument, got 2

# %% [markdown]
# # All other datatypes to bool

# %%
bool(2)
# Out:
# True

# %%
bool(-5.2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2+6j)
# Out:
# True

# %%
bool('20')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool(2.3)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool('zero')
# Out:
# True

# %%
val=[20,10,30,50]
val
# Out:
# [20, 10, 30, 50]

# %%
import sys
sys.getsizeof(val)
# Out:
# 88
