# %%
import matplotlib as plt

# %%
# Import Matplotlib
import numpy as np
import pandas as pd

# %%
# Import Matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
x1=np.linspace(0,10,50)

# create a plot figure
# fig=plt.figure()

plt.plot(x1,np.sin(x1),'-')
plt.plot(x1,np.cos(x1),'--')
# plt.plot(x1,np.tan(x1),'--')
plt.show()

# %%
# create the first of two panels and set current axis
plt.subplot(2,1,1) # (row,columns,panel number)
plt.plot(x1,np.cos(x1),'*')

# %%
plt.show()

# %%
# create a plot figure
plt.figure()

# create the first of two panel and set current axis
plt.subplot(2,1,1) # (rows,columns,panel number)
plt.plot(x1,np.sin(x1))

# create the second of two panel and set current axis
plt.subplot(2,1,2) # (rows,columns,panel number)
plt.plot(x1,np.cos(x1))

# %%
plt.show()

# %%
# get current figure information
print(plt.gcf())
# Out:
# Figure(640x480)

# %%
# get current axis information
print(plt.gca())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
plt.show()

# %% [markdown]
# # Visualization with pyplot

# %%
plt.plot([1,2,3,4],[1,8,2,16])
plt.ylabel('Numbers')
plt.show()

# %% [markdown]
# # plot() - A versatile command

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,8,27,64])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.show()

# %% [markdown]
# # State-machine interface

# %%
x=np.linspace(0,2,100)

plt.plot(x,x, label='linear')
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()
plt.show()

# %% [markdown]
# # Formatting the style of plot

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'rv')
plt.axis([0,6,0,20])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'r^')
plt.axis([0,6,0,20])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'rd')
plt.axis([0,6,0,20])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'rH')
plt.axis([0,6,0,20])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'rp')
plt.axis([0,6,0,20])
plt.show()

# %% [markdown]
# # Working with NumPy arrays

# %%
# evenly sampled time at 200ms intervals
t=np.arange(0.,5.,0.2)

# red dashes,blue squared and green triangles
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.show()

# %% [markdown]
# # Object-Oriented API

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig,ax=plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x1,np.sin(x1),'b-')
ax[1].plot(x1,np.cos(x1),'b-')

# %%
plt.show()

# %% [markdown]
# # Object and Reference

# %%
fig=plt.figure()

x2=np.linspace(0,5,10)
y2=x2**2

axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x2,y2,'r')

axes.set_xlabel('x2')
axes.set_ylabel('y2')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
plt.show()

# %% [markdown]
# # Figure and Axes

# %%
fig=plt.figure()
ax=plt.axes()

# %%
fig=plt.figure()
ax=plt.axes()
plt.show()

# %% [markdown]
# # Figure and Subplots

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,3)
ax3=fig.add_subplot(2,2,4)
ax4=fig.add_subplot(2,2,4)
plt.show()

# %% [markdown]
# # First plot with Matplotlib

# %%
plt.plot([1,3,2,4],'b-')
plt.show()

# %% [markdown]
# # Specify both Lists

# %%
x3=range(6)
plt.plot(x3,[xi**2 for xi in x3])
plt.show()

# %%
x2=np.arange(0.0,6.0,0.01)
plt.plot(x2,[xi**2 for xi in x2],'b-')
plt.show()

# %% [markdown]
# # Multiline Plots

# %%
x4=range(1,5)
plt.plot(x4,[xi*1.5 for xi in x4])
plt.plot(x4,[xi*3 for xi in x4])
plt.plot(x4,[xi/3.0 for xi in x4])
plt.show()

# %% [markdown]
# # Saving the Plot

# %%
# Saving the figure
fig.savefig('plot1.png')

# %%
# Explore the contents of figure
from IPython.display import Image
Image('plot1.png')

# %%
# Explore supported file formats
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# # Line Plot

# %%
# Create figure and axes first
fig=plt.figure()
ax=plt.axes()

# Declare a variable x5
x5=np.linspace(0,10,1000)

# Plot the sinusoid function
ax.plot(x5,np.sin(x5),'b-')

# %%
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
x7=np.linspace(0,10,30)
y7=np.sin(x7)
plt.plot(x7,y7,'o',c='k')

# %%
plt.show()

# %% [markdown]
# # Histogram

# %%
data1=np.random.randn(1000)
plt.hist(data1)
# Out:
# (array([  1.,   7.,  48., 151., 213., 265., 193.,  97.,  23.,   2.]),
#  array([-3.80714853, -3.08846631, -2.36978409, -1.65110188, -0.93241966,
#         -0.21373744,  0.50494478,  1.22362699,  1.94230921,  2.66099143,
#          3.37967365]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %% [markdown]
# # Bar Chart

# %%
data2=[5.,25.,50.,20.]
plt.bar(range(len(data2)),data2)
plt.show()

# %% [markdown]
# # Horizontal Bar Chart

# %%
data2=[5.,25.,50.,20.]
plt.barh(range(len(data2)),data2)
plt.show()

# %% [markdown]
# # Error Bar Chart

# %%
x9=np.arange(0,4,0.2)
y9=np.exp(-x9)
e1=0.1*np.abs(np.random.randn(len(y9)))
plt.errorbar(x9,y9,yerr=e1,fmt='.-')
plt.show()

# %% [markdown]
# # Stacked Bar Chart

# %%
a=[15.,30.,45.,22.]
b=[15.,25.,50.,20.]
z2=range(4)

plt.bar(z2,a,color='b')
plt.bar(z2,b,color='r',bottom=a)

plt.show()

# %% [markdown]
# # Pie Chart

# %%
plt.figure(figsize=(7,7))
x10=[35,25,20,20]
labels=['computer','electronics','mechanical','chemical']
plt.pie(x10,labels=labels)
plt.show()

# %% [markdown]
# # Boxplot

# %%
data3=np.random.randn(100)
plt.boxplot(data3)
plt.show()

# %% [markdown]
# # Area Chart

# %%
# Create same data
x12=range(1,6)
y12=[1,4,6,8,4]

# Area plot
plt.fill_between(x12,y12)
plt.show()

# %% [markdown]
# # Contour Plot

# %%
# Create a matrix
matrix1=np.random.rand(10,20)

cp=plt.contour(matrix1)
plt.show()

# %% [markdown]
# # Styles with Matplotlib Plots

# %%
# View list of all avilable styles
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# # Adding a grid

# %%
x15=np.arange(1,5)
plt.plot(x15,x15*1.5,x15,x15*3.0,x15,x15/3.0)
plt.grid(True)
plt.show()

# %% [markdown]
# # Handling axes

# %%
x15=np.arange(1,5)
plt.plot(x15,x15*1.5,x15,x15*3.0,x15/3.0)
plt.axis() # shows the current axis limits values
plt.axis([0,5,-1,13])
plt.show()

# %%
x15=np.arange(1,5)
plt.plot(x15,x15*1.5,x15,x15/3.0)
plt.xlim([1.0,4.0])
plt.ylim([0.0,12.0])
# Out:
# (0.0, 12.0)

# %%
plt.show()

# %% [markdown]
# # Handling X and Y ticks

# %%
u=[5,4,9,7,8,9,6,5,7,8]
plt.plot(u)
plt.xticks([2,4,8,10])
plt.show([2,4,6,8,10])
plt.show()

# %% [markdown]
# # Adding labels

# %%
plt.plot([1,3,2,4])
plt.xlabel('This is the X axis')
plt.ylabel('This is the Y axis')
plt.show()

# %% [markdown]
# # Adding a title

# %%
plt.plot([1,3,2,4])
plt.title('First Plot')
plt.show()

# %% [markdown]
# # Adding a legend

# %%
x15=np.arange(1,5)
fig,ax=plt.subplots()
ax.plot(x15,x15*1.5)
ax.plot(x15,x15*3.0)
ax.plot(x15,x15/3.0)
ax.legend(['Normal','Fast','Slow'])

# %%
plt.show()

# %%
x15=np.arange(1,5)
fig,ax=plt.subplots()

ax.plot(x15,x15*1.5,label='Normal')
ax.plot(x15,x15*3.0,label='Fast')
ax.plot(x15,x15/3.0,label='Slow')

ax.legend()

# %%
plt.show()

# %% [markdown]
# # Control colours

# %%
x16=np.arange(1,5)
plt.plot(x16,'r')
plt.plot(x16+1,'g')
plt.plot(x16+2,'b')
plt.show()

# %% [markdown]
# # Control line styles

# %%
x16=np.arange(1,5)
plt.plot(x16,'--',x16+1,'-.',x16+2,':')
plt.show()
